# %% [markdown]
# # Limpieza del dataset de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. El archivo contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com.
#
# El dataset fue descargado hace algunos años y en ningún caso se obtuvo beneficio económico de ello.
#
# Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos.
#
# Agrega observaciones, conclusiones o notas acerca de los datos obtenidos en cada ejercicio.

# %%
import pandas as pd

# %% [markdown]
# #### Ejercicio 00
#
# Lee el dataset data/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
df = pd.read_csv('assets/real_estate.csv', sep=';')
df
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# ## Trabajando con un DataFrame

# %% [markdown]
# #### Ejercicio 01
#
# ¿Cuál es la casa más cara del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Para visualizar el resultado utiliza un f-string. Por ejemplo:
#
# ```py
# f'La casa más cara se encuentra en la dirección: {address} y su precio es {price} €'
# ```

# %%
casa_cara = df.sort_values(by='price').tail(1)
f"La casa mas cara se encuentra en la direccion: {casa_cara['address'].values[0]} y su precio es de {casa_cara['price'].values[0]} Euros"
# Out:
# 'La casa mas cara se encuentra en la direccion: El Escorial y su precio es de 8500000 Euros'

# %% [markdown]
# La casa mas cara tiene un valor de 8.5 millones de Euros se encuentra en España precisamente en El Escorial.
# Su valor se debe a su gran tamaño y gran cantidad de habitaciones, aunque no se especifican baños ni detalles, en su descrpcion encontramos que es un palacio

# %% [markdown]
# #### Ejercicio 02
#
# ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada utilizando f-string

# %%
casa_con_precio = df[df['price'] > 0]
casa_ordenada_precio = casa_con_precio.sort_values(by='price').head(1)
f"La casa mas barata se encuentra en la direccion: {casa_ordenada_precio['address'].values[0]} y su precio es de {casa_ordenada_precio['price'].values[0]} Euros"
# Out:
# 'La casa mas barata se encuentra en la direccion: Berlin, Coslada y su precio es de 600 Euros'

# %% [markdown]
# hemos tenido que filtrar la busqueda de las casas para conseguir la mas barata con un precio, ya que existen casas con su precio a 0, lo cual da a entender que no estan a la venta o no deben tener una estimazion segun su carateisticas. igualmente se podria hacer una investigacion para conseguir su precio basandonos en su zona y calculando el m2, si existen casas en las mismas poblaciones con precio estabelcido.

# %% [markdown]
# #### Ejercicio 03
#
# ¿Cuál es la casa más grande del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas utilizando f-string

# %%
casa_con_area = df['surface'].notna()
casa_con_area = df[casa_con_area]
casa_ordenada_area = casa_con_area.sort_values(by='surface').tail(1)
f"La casa mas grande se encuentra en {casa_ordenada_area['address'].values[0]} y su superficie es de {casa_ordenada_area['surface'].values[0]}m2"
# Out:
# 'La casa mas grande se encuentra en Sevilla la Nueva y su area es de 249000.0m2'

# %% [markdown]
# Aca nuevamente se ha tenido que filtrar la busqueda para encontrar casas con valeres de superficie, probablemente se deba a falta de medidas o inclusion de datos.

# %% [markdown]
# #### Ejercicio 04
#
# ¿Cuál es la casa más pequeña del dataset? (★☆☆)

# %%
casa_con_area = df['surface'].notna()
casa_con_area = df[casa_con_area]
casa_ordenada_area = casa_con_area.sort_values(by='surface').head(1)
f"La casa mas pequeña se encuentra en {casa_ordenada_area['address'].values[0]} y su area es de {casa_ordenada_area['surface'].values[0]}m2"
# Out:
# 'La casa mas pequeña se encuentra en Calle Amparo,  Madrid Capital y su area es de 15.0m2'

# %% [markdown]
# #### Ejercicio 05.
#
# ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# - Muestra el nombre de las filas seguidas por un booleano (`True` o `False`) según contengan o no contengan NAs.
# - También muestra el nombre de las columnas seguidas por un booleano (`True` o `False`) según contengan o no contengan NAs.

# %%
for index, tiene_na in df.isna().any(axis=1).items():
  print(f'Fila {index}: {tiene_na}')
# Out:
# Fila 0: True
# Fila 1: True
# Fila 2: True
# Fila 3: True
# Fila 4: True
# Fila 5: True
# Fila 6: True
# Fila 7: True
# Fila 8: True
# Fila 9: True
# Fila 10: True
# Fila 11: True
# Fila 12: True
# Fila 13: True
# Fila 14: True
# Fila 15: True
# Fila 16: True
# Fila 17: True
# Fila 18: True
# Fila 19: True
# Fila 20: True
# Fila 21: True
# Fila 22: True
# Fila 23: True
# Fila 24: True
# Fila 25: True
# Fila 26: True
# Fila 27: True
# Fila 28: True
# Fila 29: True
# Fila 30: True
# Fila 31: True
# Fila 32: True
# Fila 33: True
# Fila 34: True
# Fila 35: True
# Fila 36: True
# Fila 37: True
# Fila 38: True
# Fila 39: True
# Fila 40: True
# Fila 41: True
# Fila 42: True
# Fila 43: True
# Fila 44: True
# Fila 45: True
# Fila 46: True
# Fila 47: True
# Fila 48: True
# Fila 49: True
# Fila 50: True
# Fila 51: True
# Fila 52: True
# Fila 53: True
# Fila 54: True
# Fila 55: True
# Fila 56: True
# Fila 57: True
# Fila 58: True
# Fila 59: True
# Fila 60: True
# Fila 61: True
# Fila 62: True
# ...

# %%
for col, tiene_na in df.isna().any(axis=0).items():
    print(f'{col}: {tiene_na}')
# Out:
# Unnamed: 0: False
# id_realEstates: False
# isNew: False
# realEstate_name: True
# phone_realEstate: True
# url_inmueble: False
# rooms: True
# bathrooms: True
# surface: True
# price: False
# date: False
# description: True
# address: False
# country: False
# level1: False
# level2: False
# level3: False
# level4: True
# level5: False
# level6: True
# level7: True
# level8: True
# upperLevel: False
# countryId: False
# level1Id: False
# level2Id: False
# level3Id: False
# level4Id: False
# level5Id: False
# level6Id: False
# level7Id: False
# level8Id: False
# accuracy: False
# latitude: False
# longitude: False
# zipCode: True
# customZone: True

# %% [markdown]
# En este ejerciico apreciamos que todas las filas poseen al menos un dato NA a diferencia de las Columnas que es mixto aunque su mayoria no contienen datos NA

# %% [markdown]
# #### Ejercicio 06.
#
# Elimina las columnas que contengan NAs del dataset, si aplica (★★☆)
#
# Muestra las dimensiones del DataFrame original y del DataFrame después de las eliminaciones.

# %%
df_sin_todos_na = df.dropna(axis=1, how="all")
f' Columnas totales: {len(df.columns)} columnas totales sin Na {len(df_sin_todos_na.columns)}'
# Out:
# ' Columnas totales: 37 columnas totales sin Na 35'

# %% [markdown]
# Aqui luego de filtrar las columnas que sean todos sus elementos NA, se eliminan dejando el DF con dos columnas menos, de 37 a 35

# %% [markdown]
# #### Ejercicio 07
#
# ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# - Muestra una lista con los nombres de las poblaciones
# - Muestra el total de las mismas

# %%
cont_poblaciones = df['level5'].value_counts()
cont_poblaciones
# Out:
# level5
#  Madrid Capital         6643
# Alcalá de Henares        525
# Las Rozas de Madrid      383
# Móstoles                 325
# Getafe                   290
#                         ...
# Fresno de Torote           1
# Pinilla del Valle          1
# Rascafría                  1
# La Hiruela                 1
# Montejo de la Sierra       1
# Name: count, Length: 168, dtype: int64

# %%
lista_poblaciones = df['level5']
lista_poblaciones.to_list()
# Out:
# ['Arganda del Rey',
#  'Fuenlabrada',
#  'Boadilla del Monte',
#  'Fuenlabrada',
#  'Arganda del Rey',
#  'Las Rozas de Madrid',
#  'Las Rozas de Madrid',
#  'Las Rozas de Madrid',
#  'Las Rozas de Madrid',
#  ' Madrid Capital',
#  ' Madrid Capital',
#  'Villaviciosa de Odón',
#  'Pinto',
#  'Valdemoro',
#  'Navalcarnero',
#  ' Madrid Capital',
#  ' Madrid Capital',
#  ' Madrid Capital',
#  'Pozuelo de Alarcón',
#  'Torrejón de Ardoz',
#  'Navalagamella',
#  'San Sebastián de los Reyes',
#  ' Madrid Capital',
#  'Rivas-vaciamadrid',
#  'Alpedrete',
#  ' Madrid Capital',
#  ' Madrid Capital',
#  ' Madrid Capital',
#  'Móstoles',
#  ' Madrid Capital',
#  ' Madrid Capital',
#  ' Madrid Capital',
#  'San Fernando de Henares',
#  'Coslada',
#  ' Madrid Capital',
#  'Becerril de la Sierra',
#  ' Madrid Capital',
#  ' Madrid Capital',
#  ' Madrid Capital',
#  ' Madrid Capital',
#  ' Madrid Capital',
#  ' Madrid Capital',
#  ' Madrid Capital',
#  ' Madrid Capital',
#  ' Madrid Capital',
# ...

# %%
f' Son un total de {len(cont_poblaciones)} poblaciones'
# Out:
# ' Son un total de 168 poblaciones'

# %% [markdown]
# vemos que al realizar la lista de poblaciones nos damos cuenta que hay muchas locaciones repetidas, pero al contarlas solo por valores da un total de 168. lo cual nos simplifica mucho la tarea de buscarlas

# %% [markdown]
# #### Ejercicio 08
#
# ¿Cuál es la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)

# %%
casas_en_arroyomolinos = df[df['level5'] == 'Arroyomolinos (Madrid)']
casas_en_arroyomolinos
# Out:
#        Unnamed: 0  id_realEstates  isNew                  realEstate_name  \
# 453           454       153843083  False                  akris arguelles
# 607           608       153620088  False        100 home red inmobiliaria
# 613           614       153478908  False               mares inmobiliaria
# 707           708       153736961  False                         gm house
# 852           853       153274493  False                         gm house
# ...           ...             ...    ...                              ...
# 15019       15020       152767314  False                 haya real estate
# 15089       15090       152767395  False                 haya real estate
# 15091       15092       152767377  False                 haya real estate
# 15094       15095       152767335  False                 haya real estate
# 15192       15193       146831440  False  miranda servicios inmobiliarios
#
#        phone_realEstate                                       url_inmueble  \
# ...

# %%
f' El promedio de precio de las casas en arroyomolinos es de {int(casas_en_arroyomolinos['price'].mean())}'
# Out:
# ' El promedio de precio de las casas eb arroyomolinos es de 294541'

# %% [markdown]
# Filtramos los datos para enfocarnos solo en una poblacion y asi buscar facilmente su precio promedio.

# %% [markdown]
# #### Ejercicio 09.
#
# ¿Los precios promedios de "Valdemorillo" y "Galapagar" son iguales? (★★☆)
#
# - Muestra ambos promedios
# - Escribe en una celda markdown una conclusión sobre ellos

# %%
casas_en_valdemorillo = df[df['level5'] == 'Valdemorillo']
casas_en_galapagar = df[df['level5'] == 'Galapagar']
media_valdemorillo = casas_en_valdemorillo['price'].mean()
media_galapagar = casas_en_galapagar['price'].mean()
f' los precios promedio de galapagar son {int(media_galapagar)} Euros y de valdemorillo son {int(media_valdemorillo)} Euros'

#
# Out:
# ' los precios promedio de galapagar son 360063 Euros y de valdemorillo son 363860 Euros'

# %% [markdown]
# Los precios de ambas ubicaciones son diferentes al hacer la comparacion genero un booleano Falso, que implica su desigualdad, ademas a primera vista se aprecia que valdemorillo tiene un valor un poco mas alto
# pero ambas zonas parecen ser similares en costos o cual podria ser similar la inversion en cada una.

# %% [markdown]
# #### Ejercicio 10
#
# ¿Los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" son iguales? (★★☆)
#
# > Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.
#
# - Muestra ambos promedios de precio por metro cuadrado
# - Escribe en una celda markdown una conclusión sobre ellos

# %%
df['pps'] = df['price'] // df['surface']
df
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %%
df_galapagar = df[df['level5'] == 'Galapagar']
df_valdemorillo = df[df['level5'] == 'Valdemorillo']


f' El valor promedio de m2 de galapagar es de: {df_galapagar.pps.mean()} y el de valdemorillo es de {df_valdemorillo.pps.mean()}'
# Out:
# ' el valor promedio de m2 de galapagar es de: 1605.88 y el de valdemorillo es de 1317.5471698113208'

# %% [markdown]
# Al buscar el precio de metro cuadrado basandonos en surface de cada una de las casas en venta en ambas zonas nos dio como resultado promedios muy diferentes en cada zona siendo el de galapagar el promedio por m2 mas alto.
# a la hora de invertir la diferencia por metro puede generar gran diferencia

# %% [markdown]
# #### Ejercicio 11
#
# ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# - Muestra el valor obtenido.

# %%
cont_inmobiliarias = df['realEstate_name'].value_counts()
f' hay: {len(cont_inmobiliarias)} inmobiliarias'
# Out:
# ' hay: 1821 inmobiliarias'

# %% [markdown]
# #### Ejercicio 12
#
# ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# - Muestra la población y el número de casas.

# %%
cont_poblaciones = df['level5'].value_counts()
cont_poblaciones.head(1)
# Out:
# level5
# Madrid Capital    6643
# Name: count, dtype: int64

# %% [markdown]
# Madrid capital es la zona con mas casas a la venta, igualmente al ser una zona tan grande lo mejor seria filtrar por niveles mas bajos o localidades mas pequeñas a la hora de querer comprar una casa o comparar precios

# %% [markdown]
# ---
#
# ## Trabajando con un subconjunto del DataFrame

# %% [markdown]
# #### Ejercicio 13
#
# Ahora vamos a trabajar con el "cinturón sur" de Madrid.
#
# Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# > Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
df_cinturon_sur = df[df['level5'].isin(["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"])]
df_cinturon_sur
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Ejercicio 14
#
# Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (★★★)
#
# > Debes usar el subset obtenido en la pregunta 13
#
# - Crea y visualiza un diccionario con todos los valores

# %%
media = df_cinturon_sur[['price','rooms', 'surface','bathrooms']].mean()
media.to_dict()
# Out:
# {'price': 223094.48070562293,
#  'rooms': 3.0177383592017737,
#  'surface': 111.75222363405337,
#  'bathrooms': 1.633221850613155}

# %%
varianza = df_cinturon_sur[['price','rooms', 'surface','bathrooms']].var()
varianza.to_dict()
# Out:
# {'price': 14921367508.04902,
#  'rooms': 0.7188858892927542,
#  'surface': 4263.051760316337,
#  'bathrooms': 0.5717968625577321}

# %% [markdown]
# #### Ejercicio 15
#
# ¿Cuál es la casa más cara de cada población del cinturón sur de Madríd? (★★☆)
#
# > Debes usar el subset obtenido en la pregunta 13
#
# - Genera un DataFrame con esta información
# - Muestra tanto la dirección como el precio de la casa seleccionada de cada población.
# - Genera conclusiones en una celda markdown

# %%
casas_caras_pobla_sur = df_cinturon_sur.loc[df_cinturon_sur.groupby('level5')['price'].idxmax()]
casas_caras_pobla_sur[['address','price']]
# Out:
#                                      address    price
# 5585                                Alcorcón   950000
# 11561  Calle de Paulo Freire, 5, Fuenlabrada   490000
# 2881                                  Getafe  1050000
# 10412           Avenida Reina Sofía, Leganés   650000

# %% [markdown]
# Reducimos la lista a nuestro Top por poblacion y vemos que Getafe es la poblacion que tiene la casa mas cara, con precio de 1.05 millones, que aun asi no se acerca a la casa mas cara de toda la muestra que era de 8.5 millones.

# %% [markdown]
# #### Ejercicio 16
#
# ¿Qué puedes decir acerca del precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? (★★☆)
#
# > Debes usar el subset obtenido en la pregunta 13
# >
# > Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
df_getafe = df_cinturon_sur[df_cinturon_sur['level5'] == 'getafe']
df_alcorcon = df_cinturon_sur[df_cinturon_sur['level5'] == 'alcorcon']


f' El valor promedio de m2 de getafe es de: {df_getafe.pps.mean()} y el de valdemorillo es de {df_alcorcon.pps.mean()}'
# Out:
# ' el valor promedio de m2 de getafe es de: nan y el de valdemorillo es de nan'

# %% [markdown]
# Al revisar los datos, en el cinturon sur vemos que los datos por metro cuadrado regresan un NA, se debe que hay celdas que no fueron rellenadas correctamente o no tenian datos de las casas en estas zonas, de igual forma podriamos hacer investigaciones sobre zonas parecidas y casas con superficies similares para asi crear un precio de cada elemento.

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# #### Ejercicio 17
#
# El proyecto proporcionó una visión clara de la estructura de precios del mercado inmobiliario, permitiendo identificar las zonas premium y las zonas más asequibles. Las capacidades de Pandas fueron fundamentales para realizar manipulaciones de datos y generar métricas  que ofrecen un panorama completo de las dinámicas de precios y ventas de las propiedades.
